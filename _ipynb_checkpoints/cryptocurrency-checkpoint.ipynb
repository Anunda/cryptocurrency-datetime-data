# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# %%
d_parser = lambda x: pd.datetime.strptime(x,'%Y-%m-%d %I-%p')
mydf = pd.read_csv("data/cryptocurrency.csv", parse_dates= ['Date'], date_parser = lambda x: pd.datetime.strptime(x,'%Y-%m-%d %I-%p'))
# Out:
# C:\Users\Dav\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
mydf
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
#mydf['Date'] = pd.to_datetime(mydf['Date'], format ='%Y-%m-%d %I-%p')

# %%
mydf.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
mydf['DayOfWeek'] = mydf['Date'].dt.day_name()

# %%
mydf
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
mydf.set_index('Date', inplace=True)

# %%
mydf
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
mydf['2019-10-12':'2020-02-01']['High'].max()
# Out:
# 199.5

# %%
mydf['Low'].resample("D").min().plot()

# %%
summ =mydf.resample('D').agg({'High':'max','Low':'min','Close':'mean','Volume':'sum'})

# %%
summ
# Out:
#               High     Low       Close        Volume
# Date
# 2017-07-01  279.99  253.23  265.284615  2.858402e+07
# 2017-07-02  293.73  255.70  269.782500  5.226229e+07
# 2017-07-03  285.00  273.07  278.882083  3.501635e+07
# 2017-07-04  282.83  265.00  276.743333  3.010991e+07
# 2017-07-05  274.97  252.67  265.025833  4.315016e+07
# ...            ...     ...         ...           ...
# 2020-03-09  208.65  189.85  200.818333  9.131404e+07
# 2020-03-10  206.28  195.17  201.577500  3.727352e+07
# 2020-03-11  202.98  181.00  195.910417  4.547683e+07
# 2020-03-12  195.64  101.22  152.763333  1.800737e+08
# 2020-03-13  148.00   90.00  124.060476  1.442618e+08
#
# [987 rows x 4 columns]

# %%
summ['change'] = (summ['High'] - summ['Low'])

# %%
summ['change'].plot()

# %%
mydf
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
cryptod = pd.read_csv('data/cryptocurrency.csv',index_col='Date',parse_dates=True)
cryptod.head(5)
# Out:
#                   Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
mydf.head(5)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# 2020-03-13 19:00:00    Friday
# 2020-03-13 18:00:00    Friday
# 2020-03-13 17:00:00    Friday
# 2020-03-13 16:00:00    Friday

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(mydf.index,mydf['Open'],c='red', label='Open')
ax.set_xlabel('Time')
ax.set_ylabel('Open',c='red')
ax.tick_params('y',colors='red')
ax2 = ax.twinx()
ax2.plot(mydf.index,mydf['Volume'],c='b',label='Volume')
ax2.set_ylabel('Volume',c='b')
ax2.tick_params('y',colors='b')
plt.show()

# %%
def cropvol(axes,x,y,xlabel,ylabel,color):
    axes.plot(x,y,color=color)
    axes.set_xlabel(xlabel)
    axes.set_xticklabels(x, rotation=45)
    axes.set_ylabel(ylabel,color=color)
    axes.tick_params('y',colors=color)

# %% [markdown]
# This is an example of how to convert visualization to functions
# Annotation of text in graphs is also shown here

# %%
fig, ax = plt.subplots(figsize=(12,10))
ax2 = ax.twinx()
cropvol(ax,mydf.index,mydf['Volume'],'Time','Volume','red')
cropvol(ax2,mydf.index,mydf['Low'],'Time','Low','blue')
ax.annotate('almost 60m', xy=(pd.Timestamp('2017-12-13'),59491228.13),xytext=(pd.Timestamp('2017-08-01'),70000000),
            arrowprops={'arrowstyle':'->','color':'green'})
plt.show()

# %%
greater = mydf[mydf['Volume']>59000000]
greater.loc['2017']['Volume']
# Out:
# Date
# 2017-12-13 14:00:00    59491228.13
# Name: Volume, dtype: float64
